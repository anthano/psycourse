# %%
from pathlib import Path

import pandas as pd

# %%
THIS_DIR = Path(".").resolve()
ROOT = THIS_DIR.parent.resolve()
DATA_DIR = ROOT / "src" / "psycourse_py" / "data"
LIPIDOMICS_DIR = DATA_DIR / "lipidomics"
# Out:
# /Users/anojat/Documents/psycourse/src/psycourse_py/data/lipidomics

# %%
sample_description = pd.read_csv(
    LIPIDOMICS_DIR / "sample_description.csv", delimiter=";"
)
matched_peaks = pd.read_csv(LIPIDOMICS_DIR / "matchedpeaks.csv", delimiter=",")
lipid_intensities = pd.read_csv(LIPIDOMICS_DIR / "lipid_intensities.csv", delimiter=",")
annotations = pd.read_csv(LIPIDOMICS_DIR / "annotation.csv", delimiter=",")

# %%
sample_description.head()
# Out:
#    ind sex   age            bmi diagnosis Patient_ID STARLIMS_sic clinic  \
# 0   88   F  42.0            NaN        b1    gxyw282      ouge616    UMG
# 1   35   F  51.0  3.244.672.328         s    qala449      hqed015    UMG
# 2   97   F  28.0    212.585.034        b1    cfci956      fkam270    LMU
# 3   11   F  55.0  2.621.882.086        b1    jhod839      kziq723    UMG
# 4   49   F  24.0    212.585.034        b1    nqem946      aghl776    UMG
#
#      year repeated visit (delete)
# 0  2012.0                      NO
# 1  2012.0                     YES
# 2  2013.0                     YES
# 3  2013.0                      NO
# 4  2013.0                      NO

# %%
matched_peaks.head()
# Out:
#    Unnamed: 0          CHIN          GER          RUS asinManuscript
# 0           0   chpeakpos54   gpeakpos75   rpeakpos51      peakpos51
# 1           1  chpeakpos313  gpeakpos366  rpeakpos201     peakpos201
# 2           2  chpeakpos378  gpeakpos430  rpeakpos210     peakpos210
# 3           3  chpeakpos573  gpeakpos641  rpeakpos312     peakpos312
# 4           4  chpeakpos591  gpeakpos654  rpeakpos320     peakpos320

# %%
lipid_intensities
# Out:
#      originalMS#  gpeakpos75  gpeakpos366  gpeakpos430  gpeakpos641  \
# 0             88   20.010132    23.737193    20.515440    19.896349
# 1             35   20.970653    22.350294    21.841468    18.469919
# 2             97   20.230461    22.168165    21.080258    17.555959
# 3             11   20.369300    25.555585    21.372413    19.436745
# 4             49   20.663592    23.165646    21.275192    19.593324
# ..           ...         ...          ...          ...          ...
# 754          985   20.688943    23.498907    21.653192    20.598327
# 755          989   20.720792    23.424420    21.566624    18.784941
# 756          998   20.990500    23.998636    21.926036    19.258090
# 757          980   21.099667    23.646367    21.763161    19.839383
# 758          949   20.836052    22.889142    21.266929    18.822858
#
